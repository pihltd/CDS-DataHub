# %%
import pandas as pd

# %%
htancsv = "/home/pihl/github/data-models/HTAN.model.csv"

# %%
htandf = pd.read_csv(htancsv)

# %%
htandf.head()
# Out:
#     Attribute                                        Description Valid Values  \
# 0       Assay  A planned process with the objective to produc...          NaN
# 1      Device  A thing made or adapted for a particular purpo...          NaN
# 2  Sequencing       Module for next generation sequencing assays          NaN
# 3   Component  Category of metadata (e.g. Diagnosis, Biospeci...          NaN
# 4     Patient                                       HTAN patient          NaN
#
#                         DependsOn  Properties  Required               Parent  \
# 0                             NaN         NaN     False                  NaN
# 1                             NaN         NaN     False                Assay
# 2                             NaN         NaN     False                Assay
# 3                             NaN         NaN      True                  NaN
# 4  Component, HTAN Participant ID         NaN     False  Individual Organism
#
# ...

# %%
columnlist = htandf.columns.values.tolist()

# %%
print(columnlist)
# Out:
# ['Attribute', 'Description', 'Valid Values', 'DependsOn', 'Properties', 'Required', 'Parent', 'DependsOn Component', 'Source', 'Validation Rules']

# %%
htandf.groupby("Parent")["Attribute"].count()
# Out:
# Parent
#  Imaging Level 4                                                                                                        1
# Acute Lymphoblastic Leukemia Tier 3                                                                                     4
# Assay                                                                                                                  27
# Biosample                                                                                                               3
# Biospecimen                                                                                                            64
# Breast Cancer Tier 3                                                                                                   31
# Bulk Methylation Assay Type                                                                                             3
# ...

# %%
newdf = htandf.groupby(['Parent','Attribute'])

# %%
newdf.head()
# Out:
#                                     Attribute  \
# 1                                      Device
# 2                                  Sequencing
# 4                                     Patient
# 5                                        File
# 8                                    Checksum
# ...                                       ...
# 1001                           Tile overlap Y
# 1002  Barretts Esophagus Goblet Cells Present
# 1003                  Pancreatitis Onset Year
# 1004          HTAN Parent Channel Metadata ID
# 1005                   Single Nucleus Capture
#
#                                             Description          Valid Values  \
# 1     A thing made or adapted for a particular purpo...                   NaN
# 2          Module for next generation sequencing assays                   NaN
# 4                                          HTAN patient                   NaN
# 5     A type of Information Content Entity specific ...                   NaN
# ...

# %%
newdf = htandf.loc[htandf['Parent'] == 'Assay']

# %%
newdf.head()
# Out:
#           Attribute                                        Description  \
# 1            Device  A thing made or adapted for a particular purpo...
# 2        Sequencing       Module for next generation sequencing assays
# 37      Other Assay  Metadata applying to any assay without standar...
# 38       Assay Type  The type and level of assay this metadata appl...
# 69  Imaging Level 1                                   Raw imaging data
#
#    Valid Values                                          DependsOn  \
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 37          NaN  Component, Filename, File Format, HTAN Parent ...
# 38          NaN                                                NaN
# 69          NaN  Component, Filename, File Format, HTAN Parent ...
#
#     Properties  Required Parent DependsOn Component  \
# 1          NaN     False  Assay                 NaN
# ...
